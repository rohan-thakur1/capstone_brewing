# %% [markdown]
# # In This Notebook

# %% [markdown]
# Exploratory data analysis of brewery-beer relation object from brewery-db API. This object will provide beer counts for each brewery.

# %% [markdown]
# # Setup

# %%
import os

from bkcharts import BoxPlot, Histogram, output_notebook, show
from bokeh.models import Range1d
import numpy as np
import pandas as pd

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c693c69-8e37-495c-829f-7311c67683c1">Loading BokehJS ...</span>
#     </div>

# %%
wrk = '../../../data/wrk/brewery-db/'

# %%
def rstr(df):
    return df.shape, df.apply(lambda x: [x.unique()])

# %% [markdown]
# # Load Data

# %%
# read csv data into dataframe object
fpath = os.path.abspath(os.path.join(wrk, 'brewery_beer.csv'))
bb = pd.read_csv(fpath)

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55475 entries, 0 to 55474
# Data columns (total 2 columns):
# beer_id       55475 non-null object
# brewery_id    55475 non-null object
# dtypes: object(2)
# memory usage: 866.9+ KB

# %%
rstr(bb)
# Out:
# ((55475, 2), beer_id       [[cBLTUw, OM0rIm, PvaOWz, tciJOF, DyNPlC, ZsQE...
#  brewery_id    [[qa1QZU, ANqPO1, J4UYYJ, cJio9R, YXhV4S, DBkL...
#  dtype: object)

# %% [markdown]
# # Transform Data

# %%
bb.drop_duplicates(keep='first', inplace=True)

# %%
### Get Brewery Counts by Year Added to Database
count = bb.beer_id.groupby(bb.brewery_id).count()

# %%
count = pd.DataFrame(count)

# %%
count
# Out:
#             beer_id
# brewery_id
# 00i2Hl           43
# 00wHoo            1
# 01Bp2T           33
# 01trKE           11
# 02Ne4w           39
# 02btbz            5
# 02rQpe            5
# 035gMh            9
# 03ZT7P           18
# 05F4ua            6
# 05irfI           42
# 05x7CL            2
# 06Qtx3            2
# 06ughl           18
# 07OTST            5
# 086VkE            9
# 08aIUw            1
# 09m7XP            2
# 0A0N4S           10
# 0AFuI7            1
# 0BRjKa            8
# 0C9lcL            3
# 0CdYN3            9
# 0Crnu6            1
# 0D7L7l           13
# 0DLaeo            6
# 0DpNPW            6
# 0EJAAE            5
# 0Emwuw            1
# 0FUzCh            2
# ...             ...
# zf0Of4            1
# zhO2k0           19
# zhcIH3            1
# zhrpUi           13
# zj3eXB            3
# zjXRHt            3
# zjlgow            4
# zkjGKM           12
# zmOs7X            5
# zn6uPI           10
# znowh3            2
# zo4Tui           30
# zomWCT            3
# zpGIxB           55
# zpUYUE            3
# zpyLEw            1
# zqvukM            7
# zrAAHP            9
# zrdx27            3
# zs7jmp            7
# zsLzJs            1
# ztnLa0            7
# zu1b73            6
# zvSxNB            8
# zwAzew           13
# zwemPe           12
# zxMohP           24
# zxqbS7            4
# zyKOCp            2
# zz2QUa           13
#
# [6011 rows x 1 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# The beer count distribution by brewery is positively skewed and heteroskedastic. With a median value of 5.0 and a mean of 9.22, it appears that a relatively smaller number of breweries carry a large number of beers.

# %%
count['beer_id'].describe()
# Out:
# count    6011.000000
# mean        9.228914
# std        13.495331
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        11.000000
# max       219.000000
# Name: beer_id, dtype: float64

# %%
hist = Histogram(count['beer_id'], bins=100, title='Number of Beers Offered by Brewery Distribution')

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7da7392a-6c7c-4864-bca2-b76a8b5712d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7da7392a-6c7c-4864-bca2-b76a8b5712d3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7da7392a-6c7c-4864-bca2-b76a8b5712d3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7da7392a-6c7c-4864-bca2-b76a8b5712d3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"14fa9370-e825-4d63-82ff-22f64742c959":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ee9e403-0f2c-4dd3-ba4b-5fe82b12a0f1","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(199.380000, 201.560000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(199.380000, 201.560000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1799999999999784],"x":["200.47"],"y":[0.0]}},"id":"4ea4db12-a0eb-4897-afac-3c4aaa6d568d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d6543bd-dc9d-4971-8fe0-e5568c576140","type":"Rect"},{"attributes":{"data_source":{"id":"dad0c1fa-eac9-4d96-bb7f-9f61f35b5826","type":"ColumnDataSource"},"glyph":{"id":"0cc3a05e-cde1-430f-92f0-8450fb00cae7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e47ee0ee-4bf6-4a3e-b94a-dbd5e39028c8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0dfa89ee-c386-473f-99de-c61cc8ae27fc","type":"ColumnDataSource"},"glyph":{"id":"85a5ad88-43af-45e8-ac83-e78795535e65","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"76c61ed9-bcfc-4c29-8311-333dbbf1d18a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6890c0f2-44ed-41b8-808b-f3eea7088b88","type":"ColumnDataSource"},"glyph":{"id":"fc771d90-dba0-452f-9d88-cdde78da1ce7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"26ecb03d-e3e6-4851-bb04-30d7b86b0ba0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(42.420000, 44.600000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[15.0],"label":["(42.420000, 44.600000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1799999999999997],"x":["43.51"],"y":[7.5]}},"id":"f21243b9-d89e-44fe-aaab-537c49e474dd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"513a8878-06f0-4009-88ef-1b52e61334b9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b29f520-161a-408d-baf5-8fc3a39b519b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(72.940000, 75.120000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":["(72.940000, 75.120000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1799999999999926],"x":["74.03"],"y":[2.5]}},"id":"0d6eb386-ce7e-4675-9b27-3bdb3a869c05","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"59e00938-a77c-4e12-859c-8c28d2f88ba4","subtype":"Chart","type":"Plot"}},"id":"eacaf956-aa41-403f-a0ce-fe758b7d5deb","type":"PanTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(27.160000, 29.340000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[38.0],"label":["(27.160000, 29.340000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1799999999999997],"x":["28.25"],"y":[19.0]}},"id":"479dbb86-8cba-47be-9b74-e6d828815885","type":" ...
