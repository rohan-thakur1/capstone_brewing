# %% [markdown]
# # In This Notebook

# %% [markdown]
# Exploratory data analysis of brewery-beer relation object from brewery-db API. This object will provide beer counts for each brewery.

# %% [markdown]
# # Setup

# %%
import os

from bkcharts import BoxPlot, Histogram, output_notebook, show
from bokeh.models import Range1d
import numpy as np
import pandas as pd

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="854b6de7-7b32-48f6-b3a2-a0a4c6c324fa">Loading BokehJS ...</span>
#     </div>

# %%
wrk = '../../../data/wrk/brewery-db/'

# %%
def rstr(df):
    return df.shape, df.apply(lambda x: [x.unique()])

# %% [markdown]
# # Load Data

# %%
# read csv data into dataframe object
fpath = os.path.abspath(os.path.join(wrk, 'brewery_beer.csv'))
bb = pd.read_csv(fpath)

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54284 entries, 0 to 54283
# Data columns (total 2 columns):
# beer_id       54284 non-null object
# brewery_id    54284 non-null object
# dtypes: object(2)
# memory usage: 848.3+ KB

# %%
rstr(bb)
# Out:
# ((54284, 2), beer_id       [[cBLTUw, PvaOWz, ZsQEJt, tciJOF, DyNPlC, Rcme...
#  brewery_id    [[qa1QZU, J4UYYJ, DBkLHq, cJio9R, YXhV4S, iZqG...
#  dtype: object)

# %% [markdown]
# # Transform Data

# %%
### Get Brewery Counts by Year Added to Database
count = bb.beer_id.groupby(bb.brewery_id).count()

# %%
count = pd.DataFrame(count)

# %%
count
# Out:
#             beer_id
# brewery_id
# 00i2Hl           47
# 00wHoo            1
# 01Bp2T           25
# 01trKE           10
# 02Ne4w           42
# 02btbz            5
# 02rQpe            2
# 035gMh           10
# 03ZT7P           17
# 05F4ua            6
# 05irfI           31
# 05x7CL            2
# 06Qtx3            2
# 06ughl           16
# 07OTST            6
# 086VkE            4
# 08aIUw            1
# 09m7XP            2
# 0A0N4S            7
# 0AFuI7            3
# 0BRjKa            7
# 0C9lcL            2
# 0CdYN3            6
# 0Crnu6            1
# 0D7L7l           17
# 0DLaeo           10
# 0DpNPW            5
# 0EJAAE            5
# 0Emwuw            1
# 0FUzCh            4
# ...             ...
# zdZ2Ow            5
# zeWbuM           96
# zhO2k0           17
# zhcIH3            1
# zhrpUi           17
# zj3eXB            4
# zjXRHt            3
# zjlgow            3
# zkjGKM            7
# zmOs7X            6
# zn6uPI           13
# znowh3            1
# zo4Tui           29
# zomWCT            2
# zpGIxB           50
# zpUYUE            3
# zpyLEw            1
# zqvukM            7
# zrAAHP           10
# zrdx27            2
# zs7jmp            7
# ztnLa0            8
# zu1b73            4
# zvSxNB            9
# zwAzew           14
# zwemPe           10
# zxMohP           22
# zxqbS7            4
# zyKOCp            2
# zz2QUa           13
#
# [5971 rows x 1 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# The beer count distribution by brewery is positively skewed and heteroskedastic. With a median value of 5.0 and a mean of 9.0, it appears that a relatively smaller number of breweries carry a large number of beers.

# %%
count['beer_id'].describe()
# Out:
# count    5971.000000
# mean        9.091274
# std        13.177243
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max       204.000000
# Name: beer_id, dtype: float64

# %%
hist = Histogram(count['beer_id'], bins=100)

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b9c9ead4-96a3-4256-a9da-af96ce73b041"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b9c9ead4-96a3-4256-a9da-af96ce73b041");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b9c9ead4-96a3-4256-a9da-af96ce73b041");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b9c9ead4-96a3-4256-a9da-af96ce73b041' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7e7babb2-32ad-4d4d-8453-5e33f160bb62":{"roots":{"references":[{"attributes":{"data_source":{"id":"a3a18815-68cb-48b2-9804-5f2d23099e05","type":"ColumnDataSource"},"glyph":{"id":"2c4aa597-68d6-4d54-9a5e-fea7a42664bd","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"23ca127a-4acc-4143-85bb-2e648e6780fb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(106.560000, 108.590000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(106.560000, 108.590000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.030000000000001],"x":["107.575"],"y":[0.0]}},"id":"1139c0a4-f98d-4e5d-8c7f-c6f3415c09c6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a1f4612-2476-4edd-9a54-04fcf2e4dce1","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3bc60e11-1ec3-4138-b6be-186b37dd91eb","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.060000, 7.090000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[646.0],"label":["(5.060000, 7.090000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.0300000000000002],"x":["6.075"],"y":[323.0]}},"id":"3e4efef5-8401-435e-95cf-0de042fb8ab0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(55.810000, 57.840000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":["(55.810000, 57.840000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.030000000000001],"x":["56.825"],"y":[3.0]}},"id":"613281e0-80ef-4262-a9af-183847e6747d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(177.610000, 179.640000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(177.610000, 179.640000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.030000000000001],"x":["178.625"],"y":[0.0]}},"id":"65d6d3fa-b954-4c2e-9747-da9bf12ff292","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cab65b83-c1ee-4123-a4ba-d89c08af2831","type":"Rect"},{"attributes":{"data_source":{"id":"af5d52ff-8706-48d2-90df-5992e5e90837","type":"ColumnDataSource"},"glyph":{"id":"d318d35b-9439-4cb6-be11-7a3ef84c6e19","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d72bcee4-eeaa-4972-a5bb-eae2dbd2cfe3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6093d7e9-4e20-487d-b493-96006a016c1b","type":"ColumnDataSource"},"glyph":{"id":"8a821742-59fe-415e-b869-2101da6ad58b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4e4433af-db18-4c75-8f97-9b193494465b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(86.260000, 88.290000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(86.260000, 88.290000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.030000000000001],"x":["87.275"],"y":[1.0]}},"id":"d1023be6-03e6-4bf0-bec2-471e21960d9f","type":"ColumnDataSource"},{"attr ...
