# %% [markdown]
# # In this Notebook

# %% [markdown]
# Parse json file into separate csv files for each object. The beer data is stored in json files. Each file represents a "page" of data in the brewery-db database.

# %% [markdown]
# # Setup

# %%
import csv
from datetime import datetime
import json
import os
import pprint
from Queue import Queue
import string
from threading import Thread

from ipywidgets import FloatProgress
from IPython.display import display
import numpy as np
import pandas as pd

# %%
# create pretty printer for dict object
pp = pprint.PrettyPrinter(indent=4)

# %%
src = '../../../data/src/brewery-db/'

# %% [markdown]
# # Initial Exploration

# %%
# read json into dataframe object
fpath = os.path.abspath(os.path.join(src, '1.json'))
print(fpath)
page = pd.read_json(fpath)
# Out:
# /home/pryan/Projects/ds@b/w210/capstone/capstone_brewing/data/src/brewery-db/1.json

# %%
# get first entry
beer = page['data'][0]

# %%
# print keys
beer.keys()
# Out:
# [u'status',
#  u'isOrganic',
#  u'description',
#  u'srmId',
#  u'nameDisplay',
#  u'breweries',
#  u'style',
#  u'glasswareId',
#  u'srm',
#  u'glass',
#  u'updateDate',
#  u'abv',
#  u'styleId',
#  u'id',
#  u'statusDisplay',
#  u'createDate',
#  u'name']

# %%
# print as dict
pp.pprint(beer)
# Out:
# {   u'abv': u'11.1',
#     u'breweries': [   {   u'brandClassification': u'craft',
#                           u'createDate': u'2013-01-20 21:32:30',
#                           u'description': u'Our humble beginnings started in the Summer of 1995 in Ship Bottom, NJ. Back then we made our first batch of beer using a home brew kit that consisted of a plastic bucket, large spoon, bottling bucket and some bottle caps. We hardly knew what what would be ahead of us 16 years later! We learned a lot over the last 16 years and feel that we really refined our craft. We are a small (Nano) brewer...See More',
#                           u'established': u'2011',
#                           u'id': u'qa1QZU',
#                           u'images': {   u'icon': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-icon.png',
#                                          u'large': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-large.png',
#                                          u'medium': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-medium.png',
#                                          u'squareLarge': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-squareLarge.png',
#                                          u'squareMedium': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-squareMedium.png'},
#                           u'isMassOwned': u'N',
#                           u'isOrganic': u'N',
#                           u'locations': [   {   u'country': {   u'createDate': u'2012-01-03 02:41:33',
#                                                                 u'displayName': u'United States',
#                                                                 u'isoCode': u'US',
#                                                                 u'isoThree': u'USA',
#                                                                 u'name': u'UNITED STATES',
#                                                                 u'numberCode': 840},
#                                                 u'countryIsoCode': u'US',
#                                                 u'createDate': u'2013-01-20 21:33:44',
#                                                 u'id': u'mvsNhg',
#                                                 u'inPlanning': u'N',
#                                                 u'isClosed': u'N',
#                                                 u'isPrimary': u'Y',
#                                                 u'latitude': 39.8909454,
#                                                 u'locality': u'Wallingford',
#                                                 u'locationType': u'micro',
#                                                 u'locationTypeDisplay': u'Micro Brewery',
#                                                 u'longitude': -75.3629687,
#                                                 u'name': u'Main Brewery',
#                                                 u'openToPublic': u'Y',
#                                                 u'postalCode': u'19086',
#                                                 u'region': u'Pennsylvania',
#                                                 u'status': u'verified',
#                                                 u'statusDisplay': u'Verified',
#                                                 u'updateDate': u'2014-07-23 19:11:34',
#                                                 u'website': u'http://www.shipbottombrewery.com/',
#                                                 u'yearOpened': u'2011'}],
#                           u'name': u'Ship Bottom Brewery',
#                           u'nameShortDisplay': u'Ship Bottom',
#                           u'status': u'verified',
#                           u'statusDisplay': u'Verified',
#                           u'updateDate': u'2016-08-31 14:57:52',
#                           u'website': u'http://www.shipbottombrewery.com/'}],
#     u'createDate': u'2013-01-20 21:38:15',
#     u'description': u"Hop Heads this one's for you!  Checking in with 143 IBU's this ale punches you in the mouth with extreme bitterness then rounds out with toffee flavors and finishes with a citrus aroma.  Made with tons of US 2 Row Barley to get this to ABV 11.1%.",
#     u'glass': {   u'createDate': u'2012-01-03 02:41:33',
#                   u'id': 5,
#                   u'name': u'Pint'},
#     u'glasswareId': 5,
#     u'id': u'cBLTUw',
#     u'isOrganic': u'N',
#     u'name': u'"18" Imperial IPA 2',
#     u'nameDisplay': u'"18" Imperial IPA 2',
#     u'srm': {   u'hex': u'520907', u'id': 33, u'name': u'33'},
#     u'srmId': 33,
#     u'status': u'verified',
#     u'statusDisplay': u'Verified',
#     u'style': {   u'abvMax': u'12',
#                   u'abvMin': u'7',
#                   u'category': {   u'createDate': u'2012-03-21 20:06:45',
#                                    u'id': 3,
#                                    u'name': u'North American Origin Ales'},
#                   u'categoryId': 3,
#                   u'createDate': u'2012-03-21 20:06:46',
#                   u'description': u'Black in color, American-style imperial stouts typically have a high alcohol content. Generally characterized as very robust. The extremely rich malty flavor and aroma are balanced with assertive hopping and fruity-ester characteristics. Bitterness should be moderately high to very high and balanced with full sweet malt character. Roasted malt astringency and bitterness can be moderately perceived but should not overwhelm the overall character. Hop aroma is usually moderately-high to overwhelmingly hop-floral, -citrus or -herbal. Diacetyl (butterscotch) levels should be absent.',
#                   u'fgMax': u'1.03',
#                   u'fgMin': u'1.02',
#                   u'ibuMax': u'80',
#                   u'ibuMin': u'50',
#                   u'id': 43,
#                   u'name': u'American-Style Imperial Stout',
#                   u'ogMin': u'1.08',
#                   u'shortName': u'American Imperial Stout',
#                   u'srmMax': u'40',
#                   u'srmMin': u'40',
#                   u'updateDate': u'2015-04-07 15:28:49'},
#     u'styleId': 43,
#     u'updateDate': u'2016-08-17 16:05:54'}

# %%
for k in beer.keys():
    print(k)
    print('-' * 70)
    print(beer[k])
    print('\n')
# Out:
# status
# ----------------------------------------------------------------------
# verified
#
#
# isOrganic
# ----------------------------------------------------------------------
# N
#
#
# description
# ----------------------------------------------------------------------
# Hop Heads this one's for you!  Checking in with 143 IBU's this ale punches you in the mouth with extreme bitterness then rounds out with toffee flavors and finishes with a citrus aroma.  Made with tons of US 2 Row Barley to get this to ABV 11.1%.
#
#
# srmId
# ----------------------------------------------------------------------
# 33
#
#
# nameDisplay
# ----------------------------------------------------------------------
# "18" Imperial IPA 2
#
#
# breweries
# ----------------------------------------------------------------------
# [{u'website': u'http://www.shipbottombrewery.com/', u'established': u'2011', u'isOrganic': u'N', u'description': u'Our humble beginnings started in the Summer of 1995 in Ship Bottom, NJ. Back then we made our first batch of beer using a home brew kit that consisted of a plastic bucket, large spoon, bottling bucket and some bottle caps. We hardly knew what what would be ahead of us 16 years later! We learned a lot over the last 16 years and feel that we really refined our craft. We are a small (Nano) brewer...See More', u'isMassOwned': u'N', u'createDate': u'2013-01-20 21:32:30', u'status': u'verified', u'locations': [{u'website': u'http://www.shipbottombrewery.com/', u'inPlanning': u'N', u'isClosed': u'N', u'name': u'Main Brewery', u'statusDisplay': u'Verified', u'locality': u'Wallingford', u'openToPublic': u'Y', u'locationType': u'micro', u'region': u'Pennsylvania', u'longitude': -75.3629687, u'id': u'mvsNhg', u'countryIsoCode': u'US', u'postalCode': u'19086', u'status': u'verified', u'yearOpened': u'2011', u'country': {u'displayName': u'United States', u'name': u'UNITED STATES', u'isoThree': u'USA', u'createDate': u'2012-01-03 02:41:33', u'numberCode': 840, u'isoCode': u'US'}, u'latitude': 39.8909454, u'isPrimary': u'Y', u'createDate': u'2013-01-20 21:33:44', u'locationTypeDisplay': u'Micro Brewery', u'updateDate': u'2014-07-23 19:11:34'}], u'name': u'Ship Bottom Brewery', u'nameShortDisplay': u'Ship Bottom', u'brandClassification': u'craft', u'updateDate': u'2016-08-31 14:57:52', u'images': {u'large': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-large.png', u'medium': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-medium.png', u'squareMedium': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-squareMedium.png', u'squareLarge': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-squareLarge.png', u'icon': u'https://s3.amazonaws.com/brewerydbapi/brewery/qa1QZU/upload_ZwdBjC-icon.png'}, u'id': u'qa1QZU', u'statusDisplay': u'Verified'}]
#
#
# style
# ----------------------------------------------------------------------
# {u'category': {u'createDate': u'2012-03-21 20:06:45', u'id': 3, u'name': u'North American Origin Ales'}, u'abvMax': u'12', u'description': u'Black in color, American-style imperial stouts typically have a high alcohol content. Generally characterized as very robust. The extremely rich malty flavor and aroma are balanced with assertive hopping and fruity-ester characteristics. Bitterness should be moderately high to very high and balanced with full sweet malt character. Roasted malt astringency and bitterness can be moderately perceived but should not overwhelm the overall character. Hop aroma is usually moderately-high to overwhelmingly hop-floral, -citrus or -herbal. Diacetyl (butterscotch) levels should be absent.', u'name': u'American-Style Imperial Stout', u'createDate': u'2012-03-21 20:06:46', u'ibuMin': u'50', u'id': 43, u'srmMax': u'40', u'ibuMax': u'80', u'abvMin': u'7', u'fgMin': u'1.02', u'fgMax': u'1.03', u'shortName': u'American Imperial Stout', u'ogMin': u'1.08', u'categoryId': 3, u'srmMin': u'40', u'updateDate': u'2015-04-07 15:28:49'}
#
#
# glasswareId
# ----------------------------------------------------------------------
# 5
#
#
# srm
# ----------------------------------------------------------------------
# {u'hex': u'520907', u'id': 33, u'name': u'33'}
#
#
# glass
# ----------------------------------------------------------------------
# {u'createDate': u'2012-01-03 02:41:33', u'id': 5, u'name': u'Pint'}
#
#
# updateDate
# ----------------------------------------------------------------------
# 2016-08-17 16:05:54
#
#
# abv
# ----------------------------------------------------------------------
# 11.1
#
#
# styleId
# ----------------------------------------------------------------------
# 43
#
#
# id
# ----------------------------------------------------------------------
# cBLTUw
#
#
# statusDisplay
# ----------------------------------------------------------------------
# Verified
#
#
# createDate
# ----------------------------------------------------------------------
# 2013-01-20 21:38:15
#
#
# name
# ----------------------------------------------------------------------
# "18" Imperial IPA 2

# %% [markdown]
# # Parse and Process Data

# %% [markdown]
# <img class='inline-image' src='...' />

# %% [markdown]
# ## Create DataFrames

# %%
# get first entry
fpath = os.path.abspath(os.path.join(src, '1.json'))
page = pd.read_json(fpath)
obj = page['data'][0]

# create beers dataframe
columns = [k for k in obj.keys() if str(k) not in ['breweries', 'style', 'srm', 'glass', 'available']]
columns.extend([u'ibu', u'foodPairings', u'originalGravity', u'labels', u'servingTemperature',
                u'availableId', u'year'])
beers = pd.DataFrame(columns=columns)

# create srms dataframe
columns = [k for k in obj[u'srm'].keys()]
srms = pd.DataFrame(columns=columns)

# create srms dataframe
columns = [u'id', u'name', u'description']
availables = pd.DataFrame(columns=columns)

# create glasses dataframe
columns = [k for k in obj[u'glass'].keys()]
glasses = pd.DataFrame(columns=columns)

# create styles dataframe
columns = [k for k in obj[u'style'].keys() if str(k) not in ['category']]
styles = pd.DataFrame(columns=columns)

# create categories dataframe
columns = [k for k in obj[u'style'][u'category'].keys()]
categories = pd.DataFrame(columns=columns)

# create breweries dataframe
columns = [k for k in obj[u'breweries'][0].keys() if str(k) not in ['locations']]
breweries = pd.DataFrame(columns=columns)

# create images dataframe
columns = [k for k in obj[u'breweries'][0][u'images'].keys()]
images = pd.DataFrame(columns=columns)
images[u'brewery_id'] = np.nan

# create locations dataframe
columns = [k for k in obj[u'breweries'][0][u'locations'][0].keys() if str(k) not in ['country']]
locations = pd.DataFrame(columns=columns)

# create countries dataframe
columns = [k for k in obj[u'breweries'][0][u'locations'][0][u'country'].keys() if str(k) not in ['country']]
countries = pd.DataFrame(columns=columns)

# create brewery_beer dataframe for relationship
brewery_beer = pd.DataFrame(columns=[u'brewery_id', u'beer_id'])

# create brewery_location dataframe for relationship
brewery_location = pd.DataFrame(columns=[u'brewery_id', u'location_id'])

# %% [markdown]
# ## Parse Data

# %%
beers.columns.tolist()
# Out:
# [u'status',
#  u'isOrganic',
#  u'description',
#  u'srmId',
#  u'nameDisplay',
#  u'glasswareId',
#  u'updateDate',
#  u'abv',
#  u'styleId',
#  u'id',
#  u'statusDisplay',
#  u'createDate',
#  u'name',
#  u'ibu',
#  u'foodPairings',
#  u'originalGravity',
#  u'labels',
#  u'servingTemperature',
#  u'availableId',
#  u'year']

# %%
errors = []

# helper functions
def append_record(data, df, id='id'):
    if id is None:
        df = df.append(data, ignore_index=True)
    elif not data.iloc[0][id] in df[id].tolist():
        df = df.append(data, ignore_index=True)
    return df


def get_beer(r):
    global beers
    # build beer object
    beer = pd.DataFrame([r], columns=r.keys())
    
    for c in beer.columns:
        if c in ['breweries', 'style', 'srm', 'glass']:
            del beer[c]
    for c in beers.columns:
        if not c in beer.columns.tolist():
            beer[c] = np.nan
    
    # append to beers dataframe
    beers = append_record(beer, beers)
    
    return

def get_srm(r):
    global srms
    try:
        # get srm object
        srm = pd.DataFrame([r[u'srm']], columns=r[u'srm'].keys())
        
        # append to srms dataframe
        srms = append_record(srm, srms)
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
        
    return

def get_glass(r):
    global glasses
    try:
        # get glass object
        glass = pd.DataFrame([r[u'glass']], columns=r[u'glass'].keys())
        
        # append to glasses dataframe
        glasses = append_record(glass, glasses)
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
    
    return

def get_available(r):
    global availables
    try:
        # get category object
        available = pd.DataFrame([r[u'available']], columns=r[u'available'].keys())

        # append to categories dataframe
        availables = append_record(available, availables)
    
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
    
    return

def get_category(r):
    global categories
    try:
        # get category object
        category = pd.DataFrame([r[u'category']], columns=r[u'category'].keys())

        # append to categories dataframe
        categories = append_record(category, categories)
    
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
    
    return

def get_style(r):
    global styles
    try:
        # get style object
        style = pd.DataFrame([r[u'style']], columns=r[u'style'].keys())

        # get category object
        get_category(r[u'style'])
    
        # drop category column
        del style[u'category']
        
        # append to styles dataframe
        styles = append_record(style, styles)
    
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
    
    return

def get_images(r):
    global images
    try:
        # get images objects
        image = r[u'images'].iloc[0]
        image = pd.DataFrame([image], columns=image.keys())
        image[u'brewery_id'] = r[u'id']

        # append image record to images dataframe
        images = append_record(image, images, id=None)
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
    return

def get_country(r):
    global countries
    country = r[u'country'].iloc[0]
    country = pd.DataFrame([country], columns=country.keys())

    # append country to countries dataframe
    countries = append_record(country, countries, id=u'isoCode')
    
    return

def get_locations(r):
    global brewery_location
    global locations
    
    try:
        location_list = r[u'locations']
        location_list[u'brewery_id'] = r[u'id']

        # append locations to locations dataframe
        for location in location_list.iloc[0]:
            location = pd.DataFrame([location], columns=location.keys())
            # get country object
            get_country(location)
            
            del location[u'country']
            # append to locations dataframe
            locations = append_record(location, locations)

            # append (brewery_id, location_id) to brewery_location dataframe
            bl = pd.DataFrame({u'brewery_id': r[u'id'],
                               u'location_id': location[u'id']})
            brewery_location = append_record(bl, brewery_location, id=None)
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass
        
    return

def get_breweries(r):
    global breweries
    global brewery_beer
    try:
        brewery_list = r[u'breweries']
        for brewery in brewery_list:
            brewery = pd.DataFrame([brewery], columns=brewery.keys())
            # append brewery to breweries dataframe
            breweries = append_record(brewery, breweries)

            # get images
            get_images(brewery)

            # get locations
            get_locations(brewery)

            # append (beer_id, brewery_id) to brewery_beer dataframe
            bb = pd.DataFrame({u'brewery_id': brewery[u'id'],
                               u'beer_id': r[u'id']})
            brewery_beer = append_record(bb, brewery_beer, id=None)
    except Exception as e: 
        errors.append(dict(page=page, error=str(e)))
        pass

    return

# %%
# global variables
num_fetch_threads = 10
queue = Queue()

# build queue
pages = range(1, 1295)
for page in pages:
    q = page
    queue.put(q)

# set up progress bar
p = FloatProgress(min=0, max=queue.qsize(), description="Parsing pages")
display(p)



#define worker
def parse_data(i, q):
    while True:
        # get json 
        page_number = q.get()
        fpath = os.path.abspath(os.path.join(src, '{}.json'.format(page_number)))
        page = pd.read_json(fpath)
        
        #get beer data from json
        records = page['data']
        
        try:
            # iterate over records
            for r in records:
                get_beer(r)
                get_srm(r)
                get_glass(r)
                get_style(r)
                get_breweries(r)
        except Exception as e: 
            errors.append(dict(page=page, error=str(e)))
            pass
        
        p.value += 1
        q.task_done()

# open threads
for i in range(num_fetch_threads):
    worker = Thread(target=parse_data, args=(i, queue,))
    worker.setDaemon(True)
    worker.start()

# start task queue
queue.join()

# send errors to csv
errors = pd.DataFrame(errors)

# %%
beers.head(100)
# Out:
#       abv beerVariationId           createDate  \
# 0    11.1             NaN  2013-01-20 21:38:15
# 1    None             NaN  2012-01-03 02:42:36
# 2    None             NaN  2014-05-06 13:08:12
# 3    None             NaN  2012-01-03 02:42:37
# 4    11.5             NaN  2012-01-03 02:42:36
# 5     6.3             NaN  2015-04-16 19:04:45
# 6     3.5             NaN  2012-01-03 02:42:37
# 7    11.4             NaN  2012-01-03 02:42:36
# 8       5             NaN  2012-01-03 02:42:36
# 9     6.9             NaN  2014-06-03 11:51:34
# 10   None             NaN  2013-03-19 02:18:43
# 11    5.3             NaN  2017-06-14 13:31:29
# 12    9.5             NaN  2017-04-28 20:00:27
# 13    7.5             NaN  2015-08-28 14:09:33
# 14     10             NaN  2013-02-12 11:44:26
# 15  11.64             NaN  2014-09-10 16:07:02
# 16    8.5             NaN  2015-11-03 17:02:33
# 17     10             NaN  2015-06-12 15:16:39
# 18    5.1             NaN  2012-01-03 02:42:36
# 19   10.1             NaN  2013-02-12 11:45:03
# 20    5.8             NaN  2016-05-11 15:05:00
# 21      6             NaN  2012-01-03 02:42:36
# 22    4.8             NaN  2014-04-09 22:04:00
# 23    8.5             NaN  2012-09-06 12:44:39
# 24    7.6             NaN  2013-07-27 14:04:42
# 25     10             NaN  2015-07-17 20:19:44
# 26      7             NaN  2015-07-21 17:27:18
# 27    5.7             NaN  2015-07-28 22:37:57
# 28    5.8             NaN  2012-03-21 02:01:47
# 29    9.5             NaN  2012-01-09 18:45:11
# ..    ...             ...                  ...
# 70      6             NaN  2014-11-10 16:49:38
# 71    5.2             NaN  2017-03-03 20:45:20
# 72    4.4             NaN  2012-12-21 17:33:55
# 73   None             NaN  2015-07-21 18:41:07
# 74    7.3             NaN  2015-12-05 01:50:00
# 75    8.2             NaN  2014-11-26 20:14:57
# 76    5.1             NaN  2014-09-10 23:04:00
# 77    7.2             NaN  2016-11-21 21:53:22
# 78    5.5             NaN  2015-06-16 03:43:06
# 79    7.5             NaN  2015-03-11 18:58:53
# 80     10             NaN  2012-01-03 02:42:36
# 81    6.8             NaN  2015-04-13 12:57:20
# 82    6.6             NaN  2015-03-09 20:33:04
# 83      7             NaN  2014-09-10 02:24:31
# 84    8.1             NaN  2015-09-03 02:44:01
# 85      4             NaN  2012-01-03 02:42:36
# 86      6             NaN  2014-02-20 13:58:38
# 87     18             NaN  2012-01-03 02:42:36
# 88    7.7             NaN  2015-05-11 17:55:47
# 89      6             NaN  2015-07-12 20:00:58
# 90   8.38             NaN  2015-04-27 15:08:03
# 91    5.8             NaN  2016-02-08 17:47:37
# 92    7.8             NaN  2013-07-27 14:02:12
# 93     10             NaN  2012-01-03 02:42:36
# 94    4.7             NaN  2014-09-10 20:32:45
# 95    3.8             NaN  2012-01-03 02:42:36
# 96    4.8             NaN  2015-07-30 19:24:02
# 97      9             NaN  2013-05-09 13:16:12
# 98   None             NaN  2012-01-03 02:42:36
# 99   None             NaN  2013-04-17 13:10:58
#
#                                           description  \
# 0   Hop Heads this one's for you!  Checking in wit...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   Stephen Fraley was discussing the Civil War wh...
# 6                                                None
# 7                Der Rauch Gott (Imperial Smoked Ale)
# 8   A refreshing, golden-hued European-style pilsn...
# 9   Man Eating Sharks Infest the Atlantic!\r\n\r\n...
# 10  An assertive American style pale ale in which ...
# 11  Pale lager made with organic Pilsen malt and n...
# 12  This Double IPA pours a hazy burnt gold color ...
# 13                                               None
# 14                                               None
# 15  Like the Franco-Belgian Military Accord of 192...
# 16                    Caramel. Walnut. Toast. Luxury.
# 17  17 is an Imperial Stout brewed with huge amoun...
# 18  Not quite pale ale.  A beer cloaked in secrecy...
# 19                                               None
# 20  The second in the rotating 4-part series of pa...
# 21  (512) Pale is a copper colored American Pale A...
# 22  A velvety beer offering distinctive notes of m...
# 23                                               None
# 24  Black ale that is aggressively hopped to balan...
# 25                                               None
# 26                                               None
# 27                                               None
# 28  The big, malty scent of the Harpoon 100 Barrel...
# 29  For our 3rd Anniversary release we knew we had...
# ..                                                ...
# 70  Originally developed as a celebratory ale for ...
# 71  Clean, crisp, smooth, and supremely drinkable ...
# 72  Well balanced ruby coloured ale with plenty of...
# 73                                               None
# 74                                               None
# 75              Rye Tripel aged in White Wine Barrels
# 76  This aptly-named offering brewed from white wh...
# 77  Imperial Blonde with a medium/light body offer...
# 78                                               None
# 79  Copious amounts of Citra and Simcoe hops are u...
# 80  The Mighty Fish Brewers first produced Ten Squ...
# 81  A bright, earthy & alluring Saison infused wit...
# 82                                               None
# 83  Creamy with hints of coffee, chocolate and van...
# 84  The perfect combination of wine meets beer! Gr...
# 85  Toasty malt and plenty of local wildflower hon...
# 86  We wanted to make rye based beer that highligh...
# 87  Too extreme to be called beer? Brewed to a col...
# 88  Named in honor of the Trail Blazers' only NBA ...
# 89                                               None
# 90  Our traditional Anniversary Ale is a Strong Ir...
# 91                                               None
# 92  A light golden double-IPA with plenty of body ...
# 93  Our limited release Imperial IPA is all about ...
# 94  Traditional English Bitter that is light, easy...
# 95  Don't let the name scare you, this is an easy ...
# 96                                               None
# 97  Our first Anniversary Ale was brewed with hund...
# 98  Historically inspired, 1803 Fat Ox Ale is craf...
# 99                                               None
#
#                                          foodPairings glasswareId   ibu  \
# 0                                                None           5  None
# 1                                                None        None  None
# 2                                                None        None  None
# 3                                                None        None  None
# 4                                                None        None  None
# 5                                                None        None    32
# 6                                                None        None  None
# 7                                                None        None  None
# 8                                                None           4    32
# 9                                                None           5  None
# 10                                               None        None  None
# 11                                               None        None    30
# 12                                               None        None   100
# 13                                               None        None  None
# 14                                               None        None   110
# 15                                               None        None    82
# 16                                               None        None    30
# 17                                               None        None  None
# 18                                               None           5    20
# 19                                               None        None  None
# 20                                               None        None    51
# 21                                               None           5    30
# 22                                               None           5  None
# 23                                               None        None  None
# 24                                               None        None    80
# 25                                               None           8  None
# 26                                               None        None  None
# 27                                               None        None  None
# 28                                               None        None    40
# 29                                               None           5    22
# ..                                                ...         ...   ...
# 70                                               None        None    50
# 71                                               None        None  None
# 72                                               None           5  None
# 73                                               None        None    36
# 74                                               None        None    78
# 75                                               None        None  None
# 76                                               None        None  None
# 77                                               None        None    19
# 78                                               None           5  None
# 79                                               None        None    56
# 80                                               None           5   100
# 81                                               None        None  24.5
# 82                                               None        None    66
# 83                                               None           5    30
# 84                                               None        None  None
# 85                                               None           5  None
# 86                                               None           5  None
# 87  Smoked almonds, smoked meats, grilled lamb, gi...           5   120
# 88                                               None        None    40
# 89                                               None        None  None
# 90                                               None        None    30
# 91                                               None        None  None
# 92                                               None           6    80
# 93                                               None           5   110
# 94                                               None        None    30
# 95                                               None        None  None
# 96                                               None        None    18
# 97  Salad with goat cheese and vinaigrette dressin...           6    37
# 98                                               None           5  None
# 99                                               None        None  None
#
#         id                                        ingredients isOrganic  ...   \
# 0   cBLTUw                                                NaN         N  ...
# 1   PvaOWz                                                NaN         N  ...
# 2   DyNPlC                                                NaN         N  ...
# 3   oQR5YM                                                NaN         N  ...
# 4   hNPjUO                                                NaN         N  ...
# 5   piINy9                                                NaN         N  ...
# 6   Qg6dpg                                               None         N  ...
# 7   ySo6qj                                               None         N  ...
# 8   bClbFg                                               None         N  ...
# 9   9wNKio                                               None         N  ...
# 10  yCo3Ci                                               None         N  ...
# 11  Ga3iyq                                               None         N  ...
# 12  XxM1JQ                                               None         N  ...
# 13  O36nRt                                               None         N  ...
# 14  djxRDj                                               None         N  ...
# 15  YP4dCI                                               None         N  ...
# 16  NIaY9C                                               None         N  ...
# 17  44neoC                                               None         Y  ...
# 18  hB0QeO  {u'hops': [{u'category': u'hop', u'createDate'...         N  ...
# 19  G3gFNA                                               None         N  ...
# 20  PBEXhV                                               None         N  ...
# 21  2fXsvw  {u'hops': [{u'myrceneMax': 70, u'farneseneMax'...         N  ...
# 22  j8sDQf                                               None         N  ...
# 23  s95tMN                                               None         N  ...
# 24  wRmmdv                                               None         N  ...
# 25  k6ilhY                                               None         Y  ...
# 26  EVVV1r                                               None         N  ...
# 27  rNLFdz                                               None         Y  ...
# 28  2AWcpw                                               None         N  ...
# 29  A78JSF  {u'hops': [{u'myrceneMax': 35, u'farneseneMax'...         N  ...
# ..     ...                                                ...       ...  ...
# 70  Y3bF6e                                               None         N  ...
# 71  o5MLSy                                               None         N  ...
# 72  yJ0hci                                               None         N  ...
# 73  K67Xn2                                               None         Y  ...
# 74  6oOncF                                               None         N  ...
# 75  cBKBoK                                               None         N  ...
# 76  Ydra7E                                               None         N  ...
# 77  vJbBKT                                               None         N  ...
# 78  ThXqY8                                               None         N  ...
# 79  3BSrTW                                               None         N  ...
# 80  Ml1FV3                                               None         N  ...
# 81  lhxuiw                                               None         N  ...
# 82  Dk2xuM                                               None         N  ...
# 83  y6LrZ3                                               None         N  ...
# 84  I4diW8                                               None         N  ...
# 85  sVIbQO                                               None         N  ...
# 86  cG6leo                                               None         N  ...
# 87  EWlB8A                                               None         N  ...
# 88  kq3Bxm                                               None         Y  ...
# 89  Gb2aAs                                               None         Y  ...
# 90  q4ToLY                                               None         N  ...
# 91  RRVJtL                                               None         N  ...
# 92  TAtY2B                                               None         N  ...
# 93  dAuCwE                                               None         N  ...
# 94  OyO1U1                                               None         N  ...
# 95  n3GrA9                                               None         N  ...
# 96  L4wxFx                                               None         N  ...
# 97  MnNbtN                                               None         N  ...
# 98  aeeemz                                               None         N  ...
# 99  nxXwJd                                               None         N  ...
#
#    originalGravity servingTemperature servingTemperatureDisplay  \
# 0             None               None                       NaN
# 1             None               None                       NaN
# 2             None               None                       NaN
# 3             None               None                       NaN
# 4             None               None                       NaN
# 5             None               None                       NaN
# 6             None               None                      None
# 7             None               None                      None
# 8             None               None                      None
# 9             None               None                      None
# 10            None               None                      None
# 11            None               None                      None
# 12            None               None                      None
# 13            None               None                      None
# 14            None               None                      None
# 15            None               None                      None
# 16            None               None                      None
# 17            None               None                      None
# 18           1.048               cold      Cold - (4-7C/39-45F)
# 19            None               None                      None
# 20            None               None                      None
# 21            None               cold      Cold - (4-7C/39-45F)
# 22            None               cold      Cold - (4-7C/39-45F)
# 23            None               None                      None
# 24            None               None                      None
# 25            None               cool     Cool - (8-12C/45-54F)
# 26            None               None                      None
# 27            None               None                      None
# 28            None               None                      None
# 29            None               cold      Cold - (4-7C/39-45F)
# ..             ...                ...                       ...
# 70            None               None                      None
# 71            None               None                      None
# 72            None               None                      None
# 73            None               None                      None
# 74            None               None                      None
# 75            None               None                      None
# 76            None               None                      None
# 77            None               None                      None
# 78            None               None                      None
# 79           1.069               None                      None
# 80            None               None                      None
# 81            None               None                      None
# 82           1.065               None                      None
# 83            None               None                      None
# 84            None               None                      None
# 85            None               None                      None
# 86            None               None                      None
# 87            None               None                      None
# 88            None               None                      None
# 89            None               None                      None
# 90            None               None                      None
# 91            None               None                      None
# 92            None               None                      None
# 93            None               None                      None
# 94            None               None                      None
# 95            None               None                      None
# 96            None               None                      None
# 97            None               cold      Cold - (4-7C/39-45F)
# 98            None               None                      None
# 99            None               None                      None
#
#                                        socialAccounts srmId    status  \
# 0                                                 NaN    33  verified
# 1                                                 NaN  None  verified
# 2   [{u'handle': u'161807', u'createDate': u'2015-...  None  verified
# 3                                                None  None  verified
# 4   [{u'handle': u'40812', u'createDate': u'2014-1...  None  verified
# 5                                                None  None  verified
# 6   [{u'handle': u'89239', u'createDate': u'2015-0...  None  verified
# 7                                                None  None  verified
# 8   [{u'handle': u'141288', u'createDate': u'2014-...  None  verified
# 9                                                None  None  verified
# 10  [{u'handle': u'149462', u'createDate': u'2015-...  None  verified
# 11                                               None  None  verified
# 12                                               None  None  verified
# 13                                               None  None  verified
# 14  [{u'handle': u'https://www.beeradvocate.com/be...  None  verified
# 15  [{u'handle': u'258185', u'createDate': u'2014-...    41  verified
# 16                                               None  None  verified
# 17  [{u'handle': u'207689', u'createDate': u'2015-...    41  verified
# 18  [{u'handle': u'1314', u'createDate': u'2012-10...     9  verified
# 19  [{u'handle': u'https://www.beeradvocate.com/be...  None  verified
# 20                                               None     8  verified
# 21                                               None     7  verified
# 22                                               None  None  verified
# 23  [{u'handle': u'199041', u'createDate': u'2012-...  None  verified
# 24                                               None  None  verified
# 25                                               None  None  verified
# 26                                               None  None  verified
# 27                                               None  None  verified
# 28                                               None  None  verified
# 29  [{u'handle': u'85228', u'createDate': u'2012-0...    10  verified
# ..                                                ...   ...       ...
# 70                                               None  None  verified
# 71                                               None  None  verified
# 72  [{u'handle': u'189833', u'createDate': u'2012-...  None  verified
# 73                                               None  None  verified
# 74                                               None  None  verified
# 75                                               None  None  verified
# 76                                               None  None  verified
# 77                                               None  None  verified
# 78                                               None  None  verified
# 79                                               None  None  verified
# 80                                               None  None  verified
# 81  [{u'handle': u'950825', u'createDate': u'2015-...  None  verified
# 82                                               None  None  verified
# 83  [{u'handle': u'247635', u'createDate': u'2015-...    34  verified
# 84  [{u'handle': u'1145696', u'createDate': u'2015...  None  verified
# 85  [{u'handle': u'3007', u'createDate': u'2015-05...  None  verified
# 86                                               None  None  verified
# 87  [{u'handle': u'3950', u'createDate': u'2014-06...    21  verified
# 88                                               None  None  verified
# 89                                               None  None  verified
# 90                                               None  None  verified
# 91                                               None  None  verified
# 92  [{u'handle': u'400455', u'createDate': u'2013-...  None  verified
# 93                                               None  None  verified
# 94  [{u'handle': u'242955', u'createDate': u'2015-...  None  verified
# 95                                               None  None  verified
# 96                                               None  None  verified
# 97                                               None  None  verified
# 98  [{u'handle': u'127786', u'createDate': u'2015-...  None  verified
# 99                                               None  None  verified
#
#    statusDisplay styleId           updateDate  year
# 0       Verified      43  2016-08-17 16:05:54  None
# 1       Verified    None  2012-03-22 13:04:49  None
# 2       Verified      30  2015-12-17 11:48:16  None
# 3       Verified      42  2012-03-22 13:04:50  None
# 4       Verified      35  2014-10-09 14:32:53  None
# 5       Verified      18  2015-04-16 19:04:45  None
# 6       Verified      42  2015-05-22 15:22:58  None
# 7       Verified     129  2015-12-16 08:15:01  None
# 8       Verified      76  2015-04-10 19:05:51  None
# 9       Verified      30  2015-12-17 12:58:57  None
# 10      Verified      25  2015-06-09 15:31:38  None
# 11      Verified      79  2017-06-14 13:31:29  None
# 12      Verified      31  2017-04-28 20:00:27  None
# 13      Verified      72  2015-08-28 19:42:36  None
# 14      Verified      31  2017-01-09 18:42:32  None
# 15      Verified     132  2015-12-17 17:34:22  None
# 16      Verified      37  2016-05-05 14:04:50  None
# 17      Verified      43  2016-04-29 15:26:08  None
# 18      Verified      25  2015-12-15 23:21:11  None
# 19      Verified      32  2017-01-09 18:42:32  None
# 20      Verified      25  2016-05-11 15:05:00  None
# 21      Verified      25  2015-12-16 05:31:49  None
# 22      Verified      77  2014-11-17 19:36:02  None
# 23      Verified     132  2015-12-16 19:18:11  None
# 24      Verified      41  2015-03-18 18:14:44  None
# 25      Verified      60  2015-07-17 20:19:44  None
# 26      Verified     138  2015-07-30 13:03:33  None
# 27      Verified      32  2015-07-28 22:37:57  None
# 28      Verified      89  2012-03-22 13:05:53  None
# 29      Verified      59  2015-12-16 15:12:37  None
# ..           ...     ...                  ...   ...
# 70      Verified       2  2015-12-17 19:38:29  None
# 71      Verified      75  2017-03-03 20:45:20  None
# 72      Verified      32  2015-12-16 23:05:04  None
# 73      Verified      41  2015-07-21 18:41:07  None
# 74      Verified      31  2015-12-08 19:34:04  None
# 75      Verified      59  2015-12-17 20:03:28  None
# 76      Verified     124  2014-09-15 20:36:04  None
# 77      Verified      36  2016-11-21 21:53:22  None
# 78      Verified       5  2015-06-16 14:49:00  None
# 79      Verified      30  2015-12-17 23:00:12  None
# 80      Verified      34  2015-12-15 23:35:33  None
# 81      Verified      72  2015-04-13 14:04:30  None
# 82      Verified      30  2015-03-09 20:33:04  None
# 83      Verified      21  2015-12-17 16:43:51  None
# 84      Verified      71  2015-09-08 16:31:22  None
# 85      Verified      36  2015-05-07 14:39:54  None
# 86      Verified     117  2015-12-17 11:05:21  None
# 87      Verified      31  2015-12-15 23:33:47  None
# 88      Verified      42  2015-05-11 17:55:48  None
# 89      Verified      72  2015-07-12 20:00:58  None
# 90      Verified      33  2015-04-27 15:08:03  None
# 91      Verified     127  2016-02-08 17:47:37  None
# 92      Verified      31  2015-03-18 18:12:38  None
# 93      Verified      31  2015-12-16 12:48:01  None
# 94      Verified       3  2015-04-29 18:04:01  None
# 95      Verified       3  2012-03-22 13:05:03  None
# 96      Verified     164  2015-07-30 19:24:03  None
# 97      Verified     114  2013-05-09 13:16:12  None
# 98      Verified      13  2015-12-16 13:43:19  None
# 99      Verified    None  2013-04-17 13:11:00  None
#
# [100 rows x 23 columns]

# %%
errors.to_csv('~/Desktop/test.csv')

# %% [markdown]
# # Send to CSV Files

# %%
wrk = '../../../data/wrk/brewery-db/'

# %%
# encode strings with utf-8
def encode_str(x):
    return str(x).encode('utf-8')

# encode all string columns
def clean_row(x):
    for c in x.keys():
        if isinstance(c, str):
            x[c] = encode_str(x[c])
    return x

objects = {'beers': beers,
           'srms': srms,
           'glasses': glasses,
           'styles': styles,
           'categories': categories,
           'breweries': breweries,
           'images': images,
           'locations': locations,
           'countries': countries,
           'brewery_beer': brewery_beer,
           'brewery_location': brewery_location}

brewery_beer.drop_duplicates(keep='first', inplace=True)
brewery_location.drop_duplicates(keep='first', inplace=True)

for fname, df in objects.items():
    fpath = os.path.abspath(os.path.join(wrk, '{}.csv'.format(fname)))
    # perform transformations
    df = df.apply(lambda x: clean_row(x))
    #df.drop_duplicates(keep='first', inplace=True)
    df.to_csv(fpath, quoting=csv.QUOTE_NONNUMERIC, encoding='utf-8', index=False)
